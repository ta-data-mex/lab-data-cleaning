# %% [markdown]
# #### 1. Import pandas library

# %%
import pandas as pd

# %% [markdown]
# #### 2. Import pymysql and sqlalchemy as you have learnt in the lesson of importing/exporting data

# %%
import sys
# !{sys.executable} -m pip install pymysql sqlalchemy

import pymysql
from sqlalchemy import create_engine

# %% [markdown]
# #### 3. Create a mysql engine to set the connection to the server. Check the connection details in [this link](https://relational.fit.cvut.cz/search?tableCount%5B%5D=0-10&tableCount%5B%5D=10-30&dataType%5B%5D=Numeric&databaseSize%5B%5D=KB&databaseSize%5B%5D=MB)

# %%
engine = create_engine('mysql+pymysql://guest:relational@relational.fit.cvut.cz')

# %% [markdown]
# #### 4. Import the users table

# %%
users = pd.read_sql_query('SELECT * from stats.users', engine)

print(users)
# Out:
#           Id  Reputation        CreationDate          DisplayName  \
# 0         -1           1 2010-07-19 06:55:26            Community
# 1          2         101 2010-07-19 14:01:36         Geoff Dalgas
# 2          3         101 2010-07-19 15:34:50         Jarrod Dixon
# 3          4         101 2010-07-19 19:03:27               Emmett
# 4          5        6792 2010-07-19 19:03:57                Shane
# 5          6         457 2010-07-19 19:04:07               Harlan
# 6          7         429 2010-07-19 19:04:37                Vince
# 7          8        6764 2010-07-19 19:04:52          csgillespie
# 8         10         121 2010-07-19 19:05:40               Pierre
# 9         11         136 2010-07-19 19:06:02             wahalulu
# 10        12         101 2010-07-19 19:06:34                  Jin
# 11        13         817 2010-07-19 19:06:49              Sharpie
# 12        15          11 2010-07-19 19:07:32        hannes.koller
# ...

# %% [markdown]
# #### 5. Rename Id column to userId

# %%
users = users.rename(columns = {'Id': 'userId'})

users.head(3)
# Out:
#    userId  Reputation        CreationDate   DisplayName      LastAccessDate  \
# 0      -1           1 2010-07-19 06:55:26     Community 2010-07-19 06:55:26
# 1       2         101 2010-07-19 14:01:36  Geoff Dalgas 2013-11-12 22:07:23
# 2       3         101 2010-07-19 15:34:50  Jarrod Dixon 2014-08-08 06:42:58
#
#                        WebsiteUrl            Location  \
# 0  http://meta.stackexchange.com/  on the server farm
# 1        http://stackoverflow.com       Corvallis, OR
# 2        http://stackoverflow.com        New York, NY
#
#                                              AboutMe  Views  UpVotes  \
# 0  <p>Hi, I'm not really a person.</p>\n\n<p>I'm ...      0     5007
# 1  <p>Developer on the StackOverflow team.  Find ...     25        3
# 2  <p><a href="http://blog.stackoverflow.com/2009...     22       19
#
#    DownVotes  AccountId   Age ProfileImageUrl
# 0       1920         -1   NaN            None
# 1          0          2  37.0            None
# ...

# %% [markdown]
# #### 6. Import the posts table.

# %%
posts = pd.read_sql_query('SELECT * from stats.posts', engine)

print(posts)
# Out:
#            Id  PostTypeId  AcceptedAnswerId         CreaionDate  Score  \
# 0           1           1              15.0 2010-07-19 19:12:12     23
# 1           2           1              59.0 2010-07-19 19:12:57     22
# 2           3           1               5.0 2010-07-19 19:13:28     54
# 3           4           1             135.0 2010-07-19 19:13:31     13
# 4           5           2               NaN 2010-07-19 19:14:43     81
# 5           6           1               NaN 2010-07-19 19:14:44    152
# 6           7           1              18.0 2010-07-19 19:15:59     76
# 7           8           1               NaN 2010-07-19 19:16:21      0
# 8           9           2               NaN 2010-07-19 19:16:27     13
# 9          10           1            1887.0 2010-07-19 19:17:47     23
# 10         11           1            1201.0 2010-07-19 19:18:30      2
# 11         12           2               NaN 2010-07-19 19:18:41     20
# ...

# %% [markdown]
# #### 7. Rename Id column to postId and OwnerUserId to userId

# %%
posts = posts.rename(columns = {'Id': 'OwnerUserId'})

posts.columns
# Out:
# Index(['OwnerUserId', 'PostTypeId', 'AcceptedAnswerId', 'CreaionDate', 'Score',
#        'ViewCount', 'Body', 'OwnerUserId', 'LasActivityDate', 'Title', 'Tags',
#        'AnswerCount', 'CommentCount', 'FavoriteCount', 'LastEditorUserId',
#        'LastEditDate', 'CommunityOwnedDate', 'ParentId', 'ClosedDate',
#        'OwnerDisplayName', 'LastEditorDisplayName'],
#       dtype='object')

# %% [markdown]
# #### 8. Define new dataframes for users and posts with the following selected columns:
#     **users columns**: userId, Reputation,Views,UpVotes,DownVotes
#     **posts columns**: postId, Score,userID,ViewCount,CommentCount

# %%
user_new = users[['userId', 'Reputation', 'Views','UpVotes', 'DownVotes']].copy()
user_new.columns

posts_new = posts[['PostTypeId', 'Score', 'OwnerUserId', 'ViewCount', 'CommentCount']].copy()
posts_new.columns
# Out:
# Index(['PostTypeId', 'Score', 'OwnerUserId', 'OwnerUserId', 'ViewCount',
#        'CommentCount'],
#       dtype='object')

# %% [markdown]
# #### 8. Merge both dataframes, users and posts.
# You will need to make a [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) of posts and users dataframes.

# %%
#Uniendo dataframes con concat

data_global = pd.concat([user_new, posts_new], axis=1)
data_global.head(5)
# Out:
#    userId  Reputation   Views  UpVotes  DownVotes  PostTypeId  Score  \
# 0    -1.0         1.0     0.0   5007.0     1920.0           1     23
# 1     2.0       101.0    25.0      3.0        0.0           1     22
# 2     3.0       101.0    22.0     19.0        0.0           1     54
# 3     4.0       101.0    11.0      0.0        0.0           1     13
# 4     5.0      6792.0  1145.0    662.0        5.0           2     81
#
#    OwnerUserId  OwnerUserId  ViewCount  CommentCount
# 0            1          8.0     1278.0             1
# 1            2         24.0     8198.0             1
# 2            3         18.0     3613.0             4
# 3            4         23.0     5224.0             2
# 4            5         23.0        NaN             3

# %% [markdown]
# #### 9. How many missing values do you have in your merged dataframe? On which columns?

# %%
null_columns = data_global.isnull().sum()
print(null_columns)
# Out:
# userId          51651
# Reputation      51651
# Views           51651
# UpVotes         51651
# DownVotes       51651
# PostTypeId          0
# Score               0
# OwnerUserId         0
# OwnerUserId      1392
# ViewCount       49055
# CommentCount        0
# dtype: int64

# %% [markdown]
# #### 10. You will need to make something with missing values.  Will you clean or filling them? Explain.
# **Remember** to check the results of your code before passing to the next step

# %%
print("Proceso a limpiar las variables que tienen un NaN y pasarlas a un 0")

columnas = list(null_columns[null_columns > 2000].index)
#print(columnas)
#data_global = data_global.drop(columnas, axis=1)
#print("Columnas con mas de 2000 datos perdidos han sido borradas")

#data_global.columns
print(Procedo a rellenar espacios en Nan por 0)
data_global['OwnerUserId'] = data_global['OwnerUserId'].fillna(0)

#Borro
#data = data.drop(drop_cols, axis=1)
# Out:
# Proceso a limpiar las variables que tienen un NaN y pasarlas a un 0

# %%
print("Procedo a rellenar espacios en Nan por 0")
data_global['OwnerUserId'] = data_global['OwnerUserId'].fillna(0)
data_global.head(17)
print("Podemos observar como valores 14 y 16 han sido normalizados en 0")
# Out:
# Procedo a rellenar espacios en Nan por 0
#     PostTypeId  Score  OwnerUserId  OwnerUserId  CommentCount
# 0            1     23          1.0          8.0             1
# 1            1     22          2.0         24.0             1
# 2            1     54          3.0         18.0             4
# 3            1     13          4.0         23.0             2
# 4            2     81          5.0         23.0             3
# 5            1    152          6.0          5.0             5
# 6            1     76          7.0         38.0             3
# 7            1      0          8.0         37.0             2
# 8            2     13          9.0         50.0             3
# 9            1     23         10.0         24.0             4
# 10           1      2         11.0         34.0             2
# 11           2     20         12.0          5.0             1
# 12           2     14         13.0         23.0             4
# ...

# %%
null_columns = data_global.isnull().sum()
print(null_columns)
print("La tabla ya no contiene valores en NaN")
# Out:
# PostTypeId      0
# Score           0
# OwnerUserId     0
# OwnerUserId     0
# CommentCount    0
# dtype: int64

# %% [markdown]
# #### 11. Adjust the data types in order to avoid future issues. Which ones should be changed?

# %%
data_global.dtypes
# Out:
# PostTypeId        int64
# Score             int64
# OwnerUserId     float64
# OwnerUserId     float64
# CommentCount      int64
# dtype: object

# %%
data_global['OwnerUserId'] = data_global['OwnerUserId'].astype('int64')
data_global['OwnerUserId'] = data_global['OwnerUserId'].astype('int64')
data_global.dtypes
# Out:
# PostTypeId      int64
# Score           int64
# OwnerUserId     int64
# OwnerUserId     int64
# CommentCount    int64
# dtype: object

# %% [markdown]
# #### Bonus: Identify extreme values in your merged dataframe as you have learned in class, create a dataframe called outliers with the same columns as our data set and calculate the bounds. The values of the outliers dataframe will be the values of the merged_df that fall outside that bounds. You will need to save your outliers dataframe to a csv file on your-code folder.

# %%
stats = data_global.describe().transpose()
stats['IQR'] = stats['75%'] - stats['25%']
stats
# Out:
#                 count          mean           std   min       25%      50%  \
# PostTypeId    91976.0      1.568866      0.611743   1.0      1.00      2.0
# Score         91976.0      2.791902      4.981867 -19.0      1.00      2.0
# OwnerUserId   91976.0  56147.699465  33975.569431   1.0  25489.75  56781.5
# OwnerUserId   91976.0  16296.339654  15291.379154  -1.0   3277.00  11032.0
# CommentCount  91976.0      1.895114      2.639020   0.0      0.00      1.0
#
#                    75%       max      IQR
# PostTypeId        2.00       7.0      1.0
# Score             3.00     192.0      2.0
# OwnerUserId   85909.25  115378.0  60419.5
# OwnerUserId   27495.00   55746.0  24218.0
# CommentCount      3.00      45.0      3.0

# %%
filt_df = data_global.loc[:, data_global.columns != 'OwnerUserId']

low = .05
high = .95
quant_df = filt_df.quantile([low, high])
print(quant_df)

quant_df.to_csv("outliers.csv")
# Out:
#       PostTypeId  Score  CommentCount
# 0.05         1.0    0.0           0.0
# 0.95         2.0    9.0           7.0

# %%
print(low_variance)
# Out:
# []

# %%
data_global.drop(low_variance, axis= 1)
data_global
# Out:
#        PostTypeId  Score  OwnerUserId  OwnerUserId  CommentCount
# 0               1     23            1            8             1
# 1               1     22            2           24             1
# 2               1     54            3           18             4
# 3               1     13            4           23             2
# 4               2     81            5           23             3
# 5               1    152            6            5             5
# 6               1     76            7           38             3
# 7               1      0            8           37             2
# 8               2     13            9           50             3
# 9               1     23           10           24             4
# 10              1      2           11           34             2
# 11              2     20           12            5             1
# 12              2     14           13           23             4
# ...
